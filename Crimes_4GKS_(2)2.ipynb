# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
import plotly.express as pxn
import folium
from folium.plugins import MarkerCluster

# %%
# 1. Read the dataset
url = 'https://datos.cdmx.gob.mx/dataset/12d22477-bcf1-49ee-92aa-16a0d0a5817c/' + \
      'resource/3f308147-b1fc-49a9-92b7-e74f3f79aa9c/download/' + \
      'carpetas-de-investigacion-pgj-cdmx.csv'
df = pd.read_csv(url)

# %%
# 2. View the basic data structure and dimensions

# %%
# 3. Display some observations
df.head()
# Out:
#    id  ao_hechos mes_hechos         fecha_hechos  \
# 0   0     2016.0      Enero  2016-01-05 17:00:00
# 1   1     2017.0  Noviembre  2017-11-01 14:00:00
# 2   2     2017.0  Noviembre  2017-11-01 16:40:00
# 3   3     2015.0  Diciembre  2015-12-30 20:00:00
# 4   4     2018.0       Mayo  2018-05-16 16:00:00
#
#                                               delito  \
# 0                                  LESIONES CULPOSAS
# 1  ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 2     ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 3                                             FRAUDE
# 4                    ROBO A REPARTIDOR CON VIOLENCIA
#
#                                     categoria_delito  \
# 0                             DELITO DE BAJO IMPACTO
# 1               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA
# 2  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...
# 3                             DELITO DE BAJO IMPACTO
# 4              ROBO A REPARTIDOR CON Y SIN VIOLENCIA
#
#                              fiscalia agencia unidad_investigacion  \
# 0  INVESTIGACIÓN EN GUSTAVO A. MADERO   GAM-6               UI-1CD
# 1       INVESTIGACIÓN EN AZCAPOTZALCO    AZ-1               UI-1SD
# 2          INVESTIGACIÓN EN IZTACALCO   IZC-2               UI-1SD
# 3         INVESTIGACIÓN EN IZTAPALAPA   IZP-8               UI-1CD
# 4         INVESTIGACIÓN EN IZTAPALAPA   IZP-9               UI-2SD
#
#                           colonia_hechos      alcaldia_hechos  \
# 0                       GRANJAS MODERNAS     GUSTAVO A MADERO
# 1                                    NaN  TLALNEPANTLA DE BAZ
# 2  GABRIEL RAMOS MILLÁN SECCIÓN TLACOTAL            IZTACALCO
# 3             CONSEJO AGRARISTA MEXICANO           IZTAPALAPA
# 4         DESARROLLO URBANO QUETZALCOATL           IZTAPALAPA
#
#           fecha_inicio mes_inicio  ao_inicio              calle_hechos  \
# 0  2016-01-05 18:35:37      Enero       2016        SAN JUAN DE ARAGON
# 1  2017-11-01 16:45:20  Noviembre       2017             BENITO JUAREZ
# 2  2017-11-01 16:56:04  Noviembre       2017                   SUR 117
# 3  2016-01-05 21:12:42      Enero       2016  CUARTA CERRADA DE FRESNO
# 4  2018-05-22 10:44:45       Mayo       2018                   TARASCO
#
#                                  calle_hechos2   longitud    latitud  \
# 0                                  CALLE ANZAR -99.103527  19.481076
# 1  MUNICIPIO DE TLALNEPANTLA, ESTADO DE MEXICO        NaN        NaN
# 2                                 ORIENTE 100A -99.106072  19.395398
# 3                ENCINO (SIN REGISTRO DEL SAP) -99.055887  19.322458
# 4                                     ZAPOTECO -99.042786  19.319141
#
#                        geopoint
# 0      19.4810759998,-99.103527
# 1                           NaN
# 2  19.3953976727,-99.1060723829
# 3      19.3224579998,-99.055887
# 4  19.3191405147,-99.0427862526

# %%
# We want only the mayors from Ciudad de Mexico
df['alcaldia_hechos'].nunique() #cantidad de unicos
# Out:
# 485

# %%
df=df[df["alcaldia_hechos"].isin(['ALVARO OBREGON','AZCAPOTZALCO','BENITO JUAREZ','COYOACAN','CUAJIMALPA DE MORELOS','CUAUHTEMOC','GUSTAVO A MADERO','IZTACALCO','IZTAPALAPA','LA MAGDALENA CONTRERAS','MIGUEL HIDALGO','MILPA ALTA','TLAHUAC','TLALPAN','VENUSTIANO CARRANZA','XOCHIMILCO'])]

# %%
# Convert the values to the right type
df['alcaldia_hechos'].nunique()
# Out:
# 16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800207 entries, 0 to 808870
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    800207 non-null  int64
#  1   ao_hechos             800021 non-null  float64
#  2   mes_hechos            800021 non-null  object
#  3   fecha_hechos          800021 non-null  object
#  4   delito                800207 non-null  object
#  5   categoria_delito      800207 non-null  object
#  6   fiscalia              800207 non-null  object
#  7   agencia               800207 non-null  object
#  8   unidad_investigacion  799985 non-null  object
#  9   colonia_hechos        776763 non-null  object
#  10  alcaldia_hechos       800207 non-null  object
#  11  fecha_inicio          800207 non-null  object
#  12  mes_inicio            800207 non-null  object
#  13  ao_inicio             800207 non-null  int64
#  14  calle_hechos          798142 non-null  object
#  15  calle_hechos2         324051 non-null  object
#  16  longitud              777531 non-null  float64
#  17  latitud               777531 non-null  float64
#  18  geopoint              777531 non-null  object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 122.1+ MB

# %%
df['fecha_hechos']=df['fecha_hechos'].astype('datetime64')
df['fecha_inicio']=df['fecha_inicio'].astype('datetime64')

df['mes_hechos']=pd.Categorical(df['mes_hechos'])
df['delito']=pd.Categorical(df['delito'])
df['categoria_delito']=pd.Categorical(df['categoria_delito'])
df['unidad_investigacion']=pd.Categorical(df['unidad_investigacion'])

# %%
# Summarise the data, including dates
df.describe(datetime_is_numeric=True)
# Out:
#                   id      ao_hechos                   fecha_hechos  \
# count  800207.000000  800021.000000                         800021
# mean   404440.724969    2017.233964  2017-09-15 06:18:33.451072768
# min         0.000000    1906.000000            1906-06-02 19:00:00
# 25%    202177.500000    2016.000000            2016-11-28 10:30:00
# 50%    404476.000000    2017.000000            2017-10-27 11:30:00
# 75%    606686.500000    2018.000000            2018-08-25 13:00:00
# max    808870.000000    2019.000000            2019-06-30 23:00:00
# std    233527.398708       1.412214                            NaN
#
#                         fecha_inicio      ao_inicio       longitud  \
# count                         800207  800207.000000  777531.000000
# mean   2017-11-08 17:23:31.065400576    2017.385711     -99.137482
# min              2016-01-01 01:35:06    2016.000000     -99.342765
# 25%              2017-01-09 17:54:14    2017.000000     -99.174906
# 50%              2017-11-27 12:11:57    2017.000000     -99.142680
# 75%       2018-09-19 16:27:08.500000    2018.000000     -99.101421
# max              2019-06-30 23:56:29    2019.000000     -98.946873
# std                              NaN       1.020460       0.058753
#
#              latitud
# count  777531.000000
# mean       19.388497
# min         9.486549
# 25%        19.342264
# 50%        19.391685
# 75%        19.437588
# max        19.582490
# std         0.069692

# %%
#arreglamos estas variables porque no estan completas
#mask es un estilo de if

df['fecha_hechos']=df['fecha_hechos'].mask((df['fecha_hechos'].dt.year<2016) | (df['fecha_hechos'].isna()), df['fecha_inicio'])

df['ao_hechos']=df['ao_hechos'].mask((df['ao_hechos']<2016) | (df['ao_hechos'].isna()), df['ao_inicio'])

df['mes_hechos']=df['mes_hechos'].mask((df['mes_hechos'].isna()), df['mes_inicio'])

# %%
# How many crimes are recorded in this dataset? In which period?
print(f"There are {len(df)} crimes, from {df['fecha_inicio'].dt.date.min()} to from {df['fecha_inicio'].dt.date.max()}")
# Out:
# There are 800207 crimes, from 2016-01-01 to from 2019-06-30

# %%
# How many crimes were recorded by year?
fecha_datos=df['ao_inicio'].value_counts()
fecha_datos
# Out:
# 2018    252510
# 2017    225854
# 2016    195849
# 2019    125994
# Name: ao_inicio, dtype: int64

# %%
df = df.set_index(df["fecha_hechos"])

# %%
df.groupby(df.index.year).size().reset_index(name="abs").plot.bar(x="fecha_hechos",y="abs", tittle="crimenes")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1f41930d20f3> in <module>()
# ----> 1 df.groupby(df.index.year).size().reset_index(name="abs").plot.bar(x="fecha_hechos",y="abs", tittle="crimenes")
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1515                     label=label,
#    1516                     log=self.log,
# -> 1517                     **kwds,
#    1518                 )
#    1519             self._append_legend_handles_labels(rect, label)
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1437     @classmethod
#    1438     def _plot(cls, ax: Axes, x, y, w, start=0, log=False, **kwds):
# -> 1439         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1440
#    1441     @property
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2396                 label='_nolegend_',
#    2397                 )
# -> 2398             r.update(kwargs)
#    2399             r.get_path()._interpolation_steps = 100
#    2400             if orientation == 'vertical':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Rectangle' object has no property 'tittle'

# %%
# Show the top 5 crimes
df['ao_inicio'].value_counts().plot(kind='bar')

# %%
df.set_index('fecha_inicio',inplace=True)

# %%
df_count=df.groupby(df.index.year).size().reset_index(name='obs')
df_count
# Out:
#    fecha_inicio     obs
# 0          2016  195849
# 1          2017  225854
# 2          2018  252510
# 3          2019  125994

# %%
df_count.plot.bar(title='Crimenes por anio', x='fecha_inicio', y='obs')

# %%
# Calculate the accumulated rate of the top 5 crimes
df.groupby('delito').size()
# Out:
# delito
# ABANDONO DE PERSONA                               2806
# ABORTO                                             382
# ABUSO DE AUTORIDAD                                5324
# ABUSO DE CONFIANZA                               12910
# ABUSO SEXUAL                                      8017
#                                                  ...
# VIOLACION EQUIPARADA Y ROBO DE VEHICULO              3
# VIOLACION TUMULTUARIA                               71
# VIOLACION TUMULTUARIA EQUIPARADA POR CONOCIDO        2
# VIOLACION Y ROBO DE VEHICULO                         1
# VIOLENCIA FAMILIAR                               69007
# Length: 273, dtype: int64

# %%
df.groupby('delito').size().reset_index(name="Crimes").sort_values(by="Crimes", ascending=False).head(5)
# Out:
#                            delito  Crimes
# 272            VIOLENCIA FAMILIAR   69007
# 222               ROBO DE OBJETOS   51870
# 158  ROBO A NEGOCIO SIN VIOLENCIA   51396
# 75                         FRAUDE   44826
# 51             DENUNCIA DE HECHOS   43613

# %%
df['delito'].value_counts().head(5)
# Out:
# VIOLENCIA FAMILIAR              69007
# ROBO DE OBJETOS                 51870
# ROBO A NEGOCIO SIN VIOLENCIA    51396
# FRAUDE                          44826
# DENUNCIA DE HECHOS              43613
# Name: delito, dtype: int64

# %%
df.groupby('delito').size().reset_index(name="Crimes").sort_values(by="Crimes", ascending=False).assign(rate=lambda x: x['Crimes']/sum(x['Crimes'])*100, accum= lambda x: x['rate'].cumsum()).head(5)
# Out:
#                            delito  Crimes      rate      accum
# 272            VIOLENCIA FAMILIAR   69007  8.623644   8.623644
# 222               ROBO DE OBJETOS   51870  6.482073  15.105716
# 158  ROBO A NEGOCIO SIN VIOLENCIA   51396  6.422838  21.528554
# 75                         FRAUDE   44826  5.601801  27.130355
# 51             DENUNCIA DE HECHOS   43613  5.450215  32.580570

# %%
df.groupby('delito').size().reset_index(name="Crimes").sort_values(by="Crimes", ascending=False).assign(rate=lambda x: x['Crimes']/len(df)).head(5)
# Out:
#                            delito  Crimes      rate
# 272            VIOLENCIA FAMILIAR   69007  0.086236
# 222               ROBO DE OBJETOS   51870  0.064821
# 158  ROBO A NEGOCIO SIN VIOLENCIA   51396  0.064228
# 75                         FRAUDE   44826  0.056018
# 51             DENUNCIA DE HECHOS   43613  0.054502

# %%
# Which city has the most and the less crimes in the dataset?

# %%
df.groupby('alcaldia_hechos').size().reset_index(name="Crimes").sort_values(by="Crimes", ascending=False)
# Out:
#            alcaldia_hechos  Crimes
# 5               CUAUHTEMOC  131397
# 8               IZTAPALAPA  119926
# 6         GUSTAVO A MADERO   80097
# 2            BENITO JUAREZ   70599
# 3                 COYOACAN   54235
# 10          MIGUEL HIDALGO   53688
# 0           ALVARO OBREGON   52568
# 14     VENUSTIANO CARRANZA   46224
# 13                 TLALPAN   46179
# 1             AZCAPOTZALCO   39435
# 7                IZTACALCO   34407
# 15              XOCHIMILCO   24639
# 12                 TLAHUAC   18197
# 9   LA MAGDALENA CONTRERAS   12064
# 4    CUAJIMALPA DE MORELOS   11393
# 11              MILPA ALTA    5159

# %%
df_citys=df.groupby('alcaldia_hechos').size().reset_index(name="Crimes").sort_values(by="Crimes", ascending=False)
df_citys['Crimes']=df_citys['Crimes'].map('{:,d}'.format)
df_citys
# Out:
#            alcaldia_hechos   Crimes
# 5               CUAUHTEMOC  131,397
# 8               IZTAPALAPA  119,926
# 6         GUSTAVO A MADERO   80,097
# 2            BENITO JUAREZ   70,599
# 3                 COYOACAN   54,235
# 10          MIGUEL HIDALGO   53,688
# 0           ALVARO OBREGON   52,568
# 14     VENUSTIANO CARRANZA   46,224
# 13                 TLALPAN   46,179
# 1             AZCAPOTZALCO   39,435
# 7                IZTACALCO   34,407
# 15              XOCHIMILCO   24,639
# 12                 TLAHUAC   18,197
# 9   LA MAGDALENA CONTRERAS   12,064
# 4    CUAJIMALPA DE MORELOS   11,393
# 11              MILPA ALTA    5,159

# %%
# In each city, what are the top 3 subcities ("Colonias") with most crimes?

# %%
df.groupby(['alcaldia_hechos','colonia_hechos']).size().to_frame().rename(columns={0:'Crimes'}).sort_values(by=['alcaldia_hechos','Crimes'], ascending=[True,False]).groupby(level=0).head(3)
# Out:
#                                                          Crimes
# alcaldia_hechos        colonia_hechos
# ALVARO OBREGON         JARDINES DEL PEDREGAL               2335
#                        SAN ANGEL                           2019
#                        ZEDEC SANTA FE                      1843
# AZCAPOTZALCO           EL ROSARIO                          2820
#                        INDUSTRIAL VALLEJO                  1930
#                        CENTRO DE AZCAPOTZALCO              1796
# BENITO JUAREZ          DEL VALLE CENTRO                   12644
#                        NARVARTE                            9317
#                        PORTALES SUR                        4587
# COYOACAN               PEDREGAL DE SANTO DOMINGO           4434
#                        AJUSCO                              2377
#                        DEL CARMEN                          2348
# CUAJIMALPA DE MORELOS  CUAJIMALPA                          1693
#                        LOMAS DE SANTA FE                   1655
#                        SAN JOSÉ DE LOS CEDROS              1008
# CUAUHTEMOC             CENTRO                             28751
#                        DOCTORES                           16657
#                        ROMA NORTE                         10403
# GUSTAVO A MADERO       LINDAVISTA                          3737
#                        GUADALUPE TEPEYAC                   3208
#                        SAN FELIPE DE JESÚS                 2284
# IZTACALCO              AGRÍCOLA ORIENTAL                   6663
#                        AGRÍCOLA PANTITLAN                  5476
#                        GRANJAS MÉXICO                      3604
# IZTAPALAPA             CENTRAL DE ABASTO                   5264
#                        LOMAS DE SAN LORENZO                3060
#                        DESARROLLO URBANO QUETZALCOATL      2990
# LA MAGDALENA CONTRERAS SAN JERÓNIMO LÍDICE                 1452
#                        SAN NICOLÁS TOTOLAPAN               1008
#                        SAN BERNABÉ OCOTEPEC                 672
# MIGUEL HIDALGO         POLANCO                             7131
#                        ANAHUAC                             3796
#                        LOMAS DE CHAPULTEPEC I SECCIÓN      3196
# MILPA ALTA             CRUZTITLA (SAN ANTONIO TECOMITL)     390
#                        SANTA MARTHA (VILLA MILPA ALTA)      342
#                        SAN MIGUEL (SAN PABLO OZTOTEPEC)     340
# TLAHUAC                DEL MAR                             1121
#                        MIGUEL HIDALGO                      1058
#                        SAN FRANCISCO TLALTENCO              881
# TLALPAN                SAN ANDRÉS TOTOLTEPEC               3000
#                        TLALPAN CENTRO I                    1832
#                        HÉROES DE PADIERNA                  1798
# VENUSTIANO CARRANZA    JARDÍN BALBUENA                     4464
#                        MOCTEZUMA 2A SECCIÓN                3549
#                        ZONA CENTRO                         3060
# XOCHIMILCO             SAN GREGORIO ATLAPULCO              1607
#                        SANTIAGO TEPALCATLALPAN             1301
#                        SANTA CRUZ ACALPIXCA - PUEBLO       1223

# %%
# Do you see a trend per month or day?
df.groupby([df['fecha_hechos'].dt.year.rename('year'),df['fecha_hechos'].dt.month.rename('month')]).size().unstack('year').plot()

# %%
df.groupby([df['fecha_hechos'].dt.year.rename('year'),df['fecha_hechos'].dt.day.rename('day')]).size().unstack('year').plot()

# %%
df.groupby([df['fecha_hechos'].dt.year.rename('year'),df['fecha_hechos'].dt.dayofweek.rename('day')]).size().unstack('year').plot()

# %%
df.groupby([df['fecha_hechos'].dt.year.rename('year'),df['fecha_hechos'].dt.week.rename('week')]).size().unstack('year').plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
#map per crimes 
top_20 = df.groupby('delito').size().to_frame(name='Count').sort_values(by= 'Count', ascending=False)
#top_20
table = df[['alcaldia_hechos', 'delito']].pivot_table(index= 'alcaldia_hechos', columns= 'delito', values= 'delito', aggfunc= len).fillna(0)[top_20.index[:20]]
table
# Out:
# delito                  VIOLENCIA FAMILIAR  ROBO DE OBJETOS  \
# alcaldia_hechos
# ALVARO OBREGON                      5094.0           3091.0
# AZCAPOTZALCO                        3116.0           2639.0
# BENITO JUAREZ                       2832.0           4419.0
# COYOACAN                            4570.0           3870.0
# CUAJIMALPA DE MORELOS               1195.0            791.0
# CUAUHTEMOC                          5640.0          10291.0
# GUSTAVO A MADERO                    7509.0           4278.0
# IZTACALCO                           4348.0           1919.0
# IZTAPALAPA                         13277.0           7115.0
# LA MAGDALENA CONTRERAS              2569.0            574.0
# MIGUEL HIDALGO                      2232.0           4691.0
# MILPA ALTA                          1065.0            189.0
# TLAHUAC                             2914.0            894.0
# TLALPAN                             5264.0           2873.0
# VENUSTIANO CARRANZA                 3876.0           3297.0
# XOCHIMILCO                          3506.0            939.0
#
# delito                  ROBO A NEGOCIO SIN VIOLENCIA   FRAUDE  \
# alcaldia_hechos
# ALVARO OBREGON                                3242.0   2595.0
# AZCAPOTZALCO                                  3293.0   1691.0
# BENITO JUAREZ                                 6076.0   6461.0
# COYOACAN                                      3919.0   3002.0
# CUAJIMALPA DE MORELOS                          903.0    770.0
# CUAUHTEMOC                                    8095.0  11863.0
# GUSTAVO A MADERO                              5560.0   3070.0
# IZTACALCO                                     1072.0   1322.0
# IZTAPALAPA                                    8026.0   3524.0
# LA MAGDALENA CONTRERAS                         321.0    478.0
# MIGUEL HIDALGO                                3632.0   4642.0
# MILPA ALTA                                     123.0    168.0
# TLAHUAC                                        468.0    588.0
# TLALPAN                                       3031.0   2296.0
# VENUSTIANO CARRANZA                           2757.0   1529.0
# XOCHIMILCO                                     878.0    827.0
#
# delito                  DENUNCIA DE HECHOS  AMENAZAS  \
# alcaldia_hechos
# ALVARO OBREGON                      2980.0    2464.0
# AZCAPOTZALCO                        1447.0    2288.0
# BENITO JUAREZ                       3309.0    2452.0
# COYOACAN                            3274.0    2583.0
# CUAJIMALPA DE MORELOS                435.0     455.0
# CUAUHTEMOC                          9216.0    5129.0
# GUSTAVO A MADERO                    4170.0    3548.0
# VENUSTIANO CARRANZA                                              0.063128
# XOCHIMILCO                                                       0.037382
#
# delito                   DESPOJO  ROBO A NEGOCIO CON VIOLENCIA  \
# alcaldia_hechos
# ALVARO OBREGON          0.057371                      0.076015
# AZCAPOTZALCO            0.055435                      0.049855
# BENITO JUAREZ           0.072380                      0.063860
# COYOACAN                0.059469                      0.053906
# CUAJIMALPA DE MORELOS   0.020657                      0.006782
# CUAUHTEMOC              0.128863                      0.113626
# GUSTAVO A MADERO        0.106028                      0.119264
# IZTACALCO               0.041072                      0.056373
# IZTAPALAPA              0.130154                      0.185502
# LA MAGDALENA CONTRERAS  0.017349                      0.010482
# MIGUEL HIDALGO          0.055112                      0.093632
# MILPA ALTA              0.011619                      0.003171
# TLAHUAC                 0.048656                      0.035233
# TLALPAN                 0.079722                      0.040870
# VENUSTIANO CARRANZA     0.052610                      0.052233
# XOCHIMILCO              0.063504                      0.039197
#
# delito                  NARCOMENUDEO POSESION SIMPLE  \
# alcaldia_hechos
# ALVARO OBREGON                              0.050406
# AZCAPOTZALCO                                0.027282
# BENITO JUAREZ                               0.018053
# COYOACAN                                    0.067748
# CUAJIMALPA DE MORELOS                       0.009635
# CUAUHTEMOC                                  0.192698
# GUSTAVO A MADERO                            0.135497
# IZTACALCO                                   0.023225
# IZTAPALAPA                                  0.214503
# LA MAGDALENA CONTRERAS                      0.009432
# MIGUEL HIDALGO                              0.067546
# MILPA ALTA                                  0.004767
# TLAHUAC                                     0.025761
# TLALPAN                                     0.025862
# VENUSTIANO CARRANZA                         0.106491
# XOCHIMILCO                                  0.021095
#
# delito                  LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION
# alcaldia_hechos
# ALVARO OBREGON                                                   0.054400
# AZCAPOTZALCO                                                     0.048253
# BENITO JUAREZ                                                    0.083700
# COYOACAN                                                         0.068743
# CUAJIMALPA DE MORELOS                                            0.011986
# CUAUHTEMOC                                                       0.147936
# GUSTAVO A MADERO                                                 0.124373
# IZTACALCO                                                        0.048561
# IZTAPALAPA                                                       0.136769
# LA MAGDALENA CONTRERAS                                           0.011679
# MIGUEL HIDALGO                                                   0.061469
# MILPA ALTA                                                       0.011167
# TLAHUAC                                                          0.028583
# TLALPAN                                                          0.058293
# VENUSTIANO CARRANZA                                              0.076427
# XOCHIMILCO                                                       0.027661

# %%
#creo el mapa con una tecnica con matplotlib
fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(table_sc_cities, cmap="hot_r")
ax.set_xticks(np.arange(table_sc_cities.shape[1]))
ax.set_yticks(np.arange(table_sc_cities.shape[0]))
ax.set_xticklabels(table_sc_cities.columns.to_list())
ax.set_yticklabels(table_sc_cities.index.to_list())
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
plt.colorbar(im)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(table_sc_crimes, cmap="hot_r")
ax.set_xticks(np.arange(table_sc_crimes.shape[1]))
ax.set_yticks(np.arange(table_sc_crimes.shape[0]))
ax.set_xticklabels(table_sc_crimes.columns.to_list())
ax.set_yticklabels(table_sc_crimes.index.to_list())
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
319514,0.06926232805084064,0.04400716796471156,0.061530147456187755,0.08085574956740602,0.10408343496362336,0.08147980027235588,0.11416869909346096,0.08447103338957918,0.05201461207131563,0.06560805577072037,0.08911206759126415,0.05946905511175664,0.05390645644323087,0.06774847870182556,0.0687429566642762],[0.017317083774109874,0.01524966261808367,0.017569460658416997,0.017177530897247134,0.009974090294178341,0.01220068109296651,0.004204286994279413,0.0032810931830463985,0.005899008966493629,0.01543378611379789,0.017657739446209714,0.015323731075422209,0.008232346474408141,0.003543972520582302,0.022773044151820295,0.024071417184760083,0.02065682239974179,0.006782348277988197,0.009634888438133874,0.011986476795410306],[0.0817308389004014,0.19839984576826683,0.15750252937971826,0.26464551822602955,0.2113131405773508,0.13753251280401146,0.18719415535185058,0.16162279008723848,0.1565596979707409,0.10353673409310736,0.09709487063095779,0.1685150246192076,0.06105230863629391,0.3299165803391309,0.14647560030983733,0.11254583134066634,0.12886306786088922,0.11362635426759447,0.1926977687626775,0.14793566232967933],[0.10881504 ...

# %%
crime = 'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA'
df_rob=df[df['delito']==crime][['delito','longitud','latitud','fecha_hechos']]
df_rob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 25906 entries, 2018-05-22 10:52:18 to 2017-09-21 13:35:23
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   delito        25906 non-null  category
#  1   longitud      25848 non-null  float64
#  2   latitud       25848 non-null  float64
#  3   fecha_hechos  25906 non-null  datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(2)
# memory usage: 870.4 KB

# %%
df_rob=df_rob[df_rob['longitud'].notna()]
df_rob
# Out:
#                                                          delito   longitud  \
# fecha_inicio
# 2018-05-22 10:52:18  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.111563
# 2018-05-22 11:09:00  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.177100
# 2018-05-26 14:30:07  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.207023
# 2016-01-14 22:49:52  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.136263
# 2018-05-27 09:42:11  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.184369
# ...                                                         ...        ...
# 2018-12-02 23:46:04  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.114986
# 2018-07-20 23:35:44  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.186887
# 2017-09-19 10:02:49  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.148276
# 2017-09-20 20:12:51  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.065493
# 2017-09-21 13:35:23  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.040473
#
#                        latitud        fecha_hechos
# fecha_inicio
# 2018-05-22 10:52:18  19.386594 2018-05-21 20:40:00
# 2018-05-22 11:09:00  19.379581 2018-05-22 06:20:00
# 2018-05-26 14:30:07  19.373796 2018-05-25 19:00:00
# 2016-01-14 22:49:52  19.557449 2016-01-14 20:40:00
# 2018-05-27 09:42:11  19.449658 2018-05-24 10:00:00
# ...                        ...                 ...
# 2018-12-02 23:46:04  19.434458 2018-12-02 23:00:00
# 2018-07-20 23:35:44  19.440038 2018-07-20 12:03:00
# 2017-09-19 10:02:49  19.425381 2017-09-18 22:45:00
# 2017-09-20 20:12:51  19.306115 2017-09-20 19:20:00
# 2017-09-21 13:35:23  19.328587 2017-09-20 15:40:00
#
# [25848 rows x 4 columns]

# %%
df_rob = df_rob.reset_index(drop=True)
df_rob = df_rob.sort_values(by = 'fecha_hechos')
fin = pd.to_datetime('2016-03-31')
df_rob['fecha_datos']= pd.to_datetime(df_rob['fecha_hechos'], format = '%Y-%m-%d')

# %%
df_rob = df_rob[df_rob['fecha_hechos']<= fin]
#df_rob['fecha_hechos']=pd.to_datetime(df_rob['fecha_hechos'].date()
df_rob
# Out:
#                                          delito   longitud    latitud  \
# 0    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.097333  19.240091
# 1    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.066642  19.350896
# 2    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.067514  19.450755
# 3    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.234479  19.370958
# 4    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.125703  19.292970
# ..                                          ...        ...        ...
# 718  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.112115  19.375599
# 719  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.175181  19.477098
# 720  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.011282  19.378033
# 721  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.113420  19.378618
# 722  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.186467  19.403736
#
#            fecha_hechos         fecha_datos
# 0   2016-01-01 01:45:00 2016-01-01 01:45:00
# 1   2016-01-01 10:00:00 2016-01-01 10:00:00
# 2   2016-01-01 12:37:46 2016-01-01 12:37:46
# 3   2016-01-01 21:30:00 2016-01-01 21:30:00
# 4   2016-01-01 21:55:00 2016-01-01 21:55:00
# ..                  ...                 ...
# 718 2016-03-30 17:20:00 2016-03-30 17:20:00
# 719 2016-03-30 19:15:00 2016-03-30 19:15:00
# 720 2016-03-30 19:30:00 2016-03-30 19:30:00
# 721 2016-03-30 22:00:00 2016-03-30 22:00:00
# 722 2016-03-30 23:00:00 2016-03-30 23:00:00
#
# [723 rows x 5 columns]

# %%
map = folium.Map()

for i in range(len(df_rob)):
  lat = df_rob['latitud'].to_list()[i]
  lon = df_rob['longitud'].to_list()[i]
  folium.Marker(location=[lat,lon],icon=folium.Icon(color='red',icon='check',prefix='fa')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_bd0856c376d58deb3371d01d26252085 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_bd0856c376d58deb3371d01d26252085&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_bd0856c376d58deb3371d01d26252085 = L.map(
#         &#x27;map_bd0856c376d58deb3371d01d26252085&#x27;, {
#         center: [0, 0],
#         zoom: 1,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_1171f64fa9a6f9f33c59e6b3f08f467d = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_bd0856c376d58deb3371d01d26252085);
#
#         var marker_f3d1f28577f4b4b7a7be78a7bc787de6 = L.marker(
#             [19.2400909998342, -99.0973329999999],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_bd0856c376d58deb3371d01d26252085);
#
#
#
#                 var icon_3f011ad312fda3bc5f3ebd922043bc4b = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_f3d1f28577f4b4b7a7be78a7bc787de6.setIcon(icon_3f011ad312fda3bc5f3ebd922043bc4b);
#
#
#         var marker_a4fb32988b63b10a5f2c905fb34a9147 = L.marker(
#             [19.3508959998335, -99.066642],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_bd0856c376d58deb3371d01d26252085);
#
#
#
#                 var icon_91e28ba9b638bb8a3936dfb227a08125 = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_a4fb32988b63b10a5f2c905fb34a9147.setIcon(icon_91e28ba9b638bb8a3936dfb227a08125);
#
#
#         var marker_9666a844e4c8a60d2c0926b959ac1ec7 = L.marker(
#             [19.4507549998334, -99.0675139999999],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_bd0856c376d58deb3371d01d26252085);
#
#
#
#                 var icon_072075bcdc4d8ac895a1d1d8930a71ad = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_9666a844e4c8a60d2c0926b959ac1ec7.setIcon(icon_072075bcdc4d8ac895a1d1d8930a71ad);
#
#
#         var marker_075d06fdc7faeb424cc38fda58e3fde5 = L.marker(
#             [19.370957999834, -99.2344789999999],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_bd0856c376d58deb3371d01d26252085);
#
#
#
#                 var icon_79889ef2b6fe07a673519c8199d855df = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_075d06fdc7faeb424cc38fda58e3fde5.setIcon(icon_79889ef2b6fe07a673519c8199d855df);
#
#
#         var marker_34cbbe93a16d4a593def887db35914aa = L.marker(
#             [19.2929699998342, -99.1257029999999],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_bd0856c376d58deb3371d01d26252085);
#
#
#
#                 var icon_f6214a548b9fb8bd2ee241a7a26a8714 = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_34cbbe93a16d4a593def887db35914aa.setIcon(icon_f6214a548b9fb8bd2ee241a7a26a8714);
#
#
#         var marker_a3d82bcc9e615722022b709af0b28dc1 = L.marker(
#             [19.4674583390162, -99.1441582565696],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_bd0856c376d58deb3371d01d26252085);
#
#
#
#                 var icon_21af6df375cf4dad2d51c681fc6043c8 = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_a3d82bcc9e615722022b709af0b28dc1.setIcon(icon_21af6df375cf4dad2d51c681fc6043c8);
#
#
#         var marker_3e901a6cdbb4266aeb9fcaf419fc2567 = L.marker(
#             [19.3957510656179, -99.2068959747003],
#             {
#                 icon: new L.Icon.Default(),
#                 }

# %%
map = folium.Map()
mc=MarkerCluster().add_to(map)

for i in range(len(df_rob)):
  lat = df_rob['latitud'].to_list()[i]
  lon = df_rob['longitud'].to_list()[i]
  folium.Marker(location=[lat,lon],icon=folium.Icon(color='red',icon='check',prefix='fa')).add_to(mc)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_683606292cebe78ee84ae0d37a00081d {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_683606292cebe78ee84ae0d37a00081d&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_683606292cebe78ee84ae0d37a00081d = L.map(
#         &#x27;map_683606292cebe78ee84ae0d37a00081d&#x27;, {
#         center: [0, 0],
#         zoom: 1,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_6ff644443c6ab17a0504a28bbc7d7d98 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_683606292cebe78ee84ae0d37a00081d);
#
#             var marker_cluster_433fa621533291072d1bb599955ef04d = L.markerClusterGroup({});
#             map_683606292cebe78ee84ae0d37a00081d.addLayer(marker_cluster_433fa621533291072d1bb599955ef04d);
#
#
#         var marker_87cd338082cbed39b76fca0cf7db4109 = L.marker(
#             [19.2400909998342, -99.0973329999999],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_433fa621533291072d1bb599955ef04d);
#
#
#
#                 var icon_9e42dbe323e16c917f38f2ad635e58b3 = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_87cd338082cbed39b76fca0cf7db4109.setIcon(icon_9e42dbe323e16c917f38f2ad635e58b3);
#
#
#         var marker_ff5ab1918378ded94265cb852b4e1ee3 = L.marker(
#             [19.3508959998335, -99.066642],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_433fa621533291072d1bb599955ef04d);
#
#
#
#                 var icon_8faf91b31ffb85d8fe2f8d5cb4fb97fb = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_ff5ab1918378ded94265cb852b4e1ee3.setIcon(icon_8faf91b31ffb85d8fe2f8d5cb4fb97fb);
#
#
#         var marker_439f3572082bb0c251ec4632b1c5a7fb = L.marker(
#             [19.4507549998334, -99.0675139999999],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_433fa621533291072d1bb599955ef04d);
#
#
#
#                 var icon_1ed24372c5d06fadee1c4e34bb299f1f = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_439f3572082bb0c251ec4632b1c5a7fb.setIcon(icon_1ed24372c5d06fadee1c4e34bb299f1f);
#
#
#         var marker_94cbc727746a43845bc984e46a51ceaf = L.marker(
#             [19.370957999834, -99.2344789999999],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_433fa621533291072d1bb599955ef04d);
#
#
#
#                 var icon_bcc2cc796e673cabbe503e9818dc8c60 = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_94cbc727746a43845bc984e46a51ceaf.setIcon(icon_bcc2cc796e673cabbe503e9818dc8c60);
#
#
#         var marker_3fda5c639c09d4a6718b46bfd4171b5c = L.marker(
#             [19.2929699998342, -99.1257029999999],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_433fa621533291072d1bb599955ef04d);
#
#
#
#                 var icon_eb4b30a324da87527912a7b381045d6f = L.AwesomeMarkers.icon({
#                     icon: &#x27;check&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;fa&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_3fda5c639c09d4a6718b46bfd4171b5c.setIcon(icon_eb4b30a324da87527912a7b381045d6f);
#
#
#         var marker_0c40cbb9c1bec85b0cb4ca856769357a = L.marker(
#             [19.4674583390162, -99.1441582565696],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_clu

# %%
df_rob
# Out:
#                                          delito   longitud    latitud  \
# 0    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.097333  19.240091
# 1    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.066642  19.350896
# 2    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.067514  19.450755
# 3    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.234479  19.370958
# 4    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.125703  19.292970
# ..                                          ...        ...        ...
# 718  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.112115  19.375599
# 719  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.175181  19.477098
# 720  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.011282  19.378033
# 721  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.113420  19.378618
# 722  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.186467  19.403736
#
#            fecha_hechos         fecha_datos
# 0   2016-01-01 01:45:00 2016-01-01 01:45:00
# 1   2016-01-01 10:00:00 2016-01-01 10:00:00
# 2   2016-01-01 12:37:46 2016-01-01 12:37:46
# 3   2016-01-01 21:30:00 2016-01-01 21:30:00
# 4   2016-01-01 21:55:00 2016-01-01 21:55:00
# ..                  ...                 ...
# 718 2016-03-30 17:20:00 2016-03-30 17:20:00
# 719 2016-03-30 19:15:00 2016-03-30 19:15:00
# 720 2016-03-30 19:30:00 2016-03-30 19:30:00
# 721 2016-03-30 22:00:00 2016-03-30 22:00:00
# 722 2016-03-30 23:00:00 2016-03-30 23:00:00
#
# [723 rows x 5 columns]

# %%
df_rob['fecha_hechos']= pd.to_datetime(df_rob['fecha_hechos']).dt.date
df_rob['fecha_hechos_str']=df_rob['fecha_hechos'].apply(lambda x: str(x))
df_rob
# Out:
#                                          delito   longitud    latitud  \
# 0    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.097333  19.240091
# 1    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.066642  19.350896
# 2    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.067514  19.450755
# 3    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.234479  19.370958
# 4    ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.125703  19.292970
# ..                                          ...        ...        ...
# 718  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.112115  19.375599
# 719  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.175181  19.477098
# 720  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.011282  19.378033
# 721  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.113420  19.378618
# 722  ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA -99.186467  19.403736
#
#     fecha_hechos         fecha_datos fecha_hechos_str
# 0     2016-01-01 2016-01-01 01:45:00       2016-01-01
# 1     2016-01-01 2016-01-01 10:00:00       2016-01-01
# 2     2016-01-01 2016-01-01 12:37:46       2016-01-01
# 3     2016-01-01 2016-01-01 21:30:00       2016-01-01
# 4     2016-01-01 2016-01-01 21:55:00       2016-01-01
# ..           ...                 ...              ...
# 718   2016-03-30 2016-03-30 17:20:00       2016-03-30
# 719   2016-03-30 2016-03-30 19:15:00       2016-03-30
# 720   2016-03-30 2016-03-30 19:30:00       2016-03-30
# 721   2016-03-30 2016-03-30 22:00:00       2016-03-30
# 722   2016-03-30 2016-03-30 23:00:00       2016-03-30
#
# [723 rows x 6 columns]

# %%
fig=px.scatter_mapbox(df_rob, lat='latitud', lon='longitud', mapbox_style='open-street-map', animation_frame='fecha_hechos_str', width=700, height=700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a2cda5bb-6603-4ae2-b49f-944e8695f549" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2cda5bb-6603-4ae2-b49f-944e8695f549")) {                    Plotly.newPlot(                        "a2cda5bb-6603-4ae2-b49f-944e8695f549",                        [{"hovertemplate":"fecha_hechos_str=2016-01-01<br>latitud=%{lat}<br>longitud=%{lon}<extra></extra>","lat":[19.2400909998342,19.3508959998335,19.4507549998334,19.370957999834,19.2929699998342],"legendgroup":"","lon":[-99.0973329999999,-99.066642,-99.0675139999999,-99.2344789999999,-99.1257029999999],"marker":{"color":"#636efa"},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinew ...
