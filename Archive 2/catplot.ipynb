# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({'id':['A','A','A','A','A','A','A','B','B','B','B','B','B','C','C'], 
                   'rating':[1,2,4,5,5,5,3,1,3,3,3,5,2,5,5]})

# %%
df['rating_cat'] = pd.Categorical(df['rating'])

# %%
df
# Out:
#    id  rating rating_cat
# 0   A       1          1
# 1   A       2          2
# 2   A       4          4
# 3   A       5          5
# 4   A       5          5
# 5   A       5          5
# 6   A       3          3
# 7   B       1          1
# 8   B       3          3
# 9   B       3          3
# 10  B       3          3
# 11  B       5          5
# 12  B       2          2
# 13  C       5          5
# 14  C       5          5

# %%
sns.catplot(data=df, x="rating", col="id", col_wrap=2, kind="count", color='Blue')
plt.show()
